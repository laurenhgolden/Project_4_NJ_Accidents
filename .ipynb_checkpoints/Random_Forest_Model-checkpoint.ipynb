# %% [markdown]
# # Instructor Do: Random Forests

# %%
# Initial imports
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import time
# %matplotlib inline

# %% [markdown]
# ## Loading NJ_Data_cleaned Encoded Data

# %%
# Loading data
nj_df = pd.read_csv("Resources/NJ_Data_cleaned.csv")
nj_df.head()
# Out:
#    Severity  Distance(mi)  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# 0         0          0.01      35.581625         93.0         29.79
# 1         0          0.01      35.581625         90.0         29.78
# 2         0          0.01      35.581625         90.0         29.78
# 3         1          0.01      35.581625         95.0         29.77
# 4         0          0.01      35.581625         90.0         29.76
#
#    Visibility(mi) Wind_Direction  Wind_Speed(mph)  Precipitation(in)  \
# 0             2.5            ENE              6.9               0.02
# 1             4.0              E             12.7               0.00
# 2             4.0              E             12.7               0.00
# 3             4.0              E              8.1               0.01
# 4             4.0            VAR              5.8               0.01
#
#   Weather_Condition  ...  Crossing  Give_Way  Junction  No_Exit  Railway  \
# ...

# %%
# Encode the data using get_dummies
nj_encoded = pd.get_dummies(nj_df)
nj_encoded.head()
# Out:
#    Severity  Distance(mi)  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# 0         0          0.01      35.581625         93.0         29.79
# 1         0          0.01      35.581625         90.0         29.78
# 2         0          0.01      35.581625         90.0         29.78
# 3         1          0.01      35.581625         95.0         29.77
# 4         0          0.01      35.581625         90.0         29.76
#
#    Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  Amenity  Bump  ...  \
# 0             2.5              6.9               0.02        0     0  ...
# 1             4.0             12.7               0.00        0     0  ...
# 2             4.0             12.7               0.00        0     0  ...
# 3             4.0              8.1               0.01        0     0  ...
# 4             4.0              5.8               0.01        0     0  ...
#
#    Weather_Condition_Thunder in the Vicinity  Weather_Condition_Thunderstorm  \
# ...

# %%
# Define features set
X = nj_encoded.copy()
X.drop("Severity", axis=1, inplace=True)
X.head()
# Out:
#    Distance(mi)  Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# 0          0.01      35.581625         93.0         29.79             2.5
# 1          0.01      35.581625         90.0         29.78             4.0
# 2          0.01      35.581625         90.0         29.78             4.0
# 3          0.01      35.581625         95.0         29.77             4.0
# 4          0.01      35.581625         90.0         29.76             4.0
#
#    Wind_Speed(mph)  Precipitation(in)  Amenity  Bump  Crossing  ...  \
# 0              6.9               0.02        0     0         0  ...
# 1             12.7               0.00        0     0         1  ...
# 2             12.7               0.00        0     0         0  ...
# 3              8.1               0.01        0     0         0  ...
# 4              5.8               0.01        0     0         0  ...
#
#    Weather_Condition_Thunder in the Vicinity  Weather_Condition_Thunderstorm  \
# ...

# %%
# Define target vector
y = nj_encoded["Severity"].ravel()
y[:5]
# Out:
# array([0, 0, 0, 1, 0], dtype=int64)

# %%
# Balance out two classes
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=0)
X_resampled, y_resampled = rus.fit_resample(X, y)
print(sorted(Counter(y_resampled).items()))
# Out:
# [(0, 26906), (1, 26906)]

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, random_state=78)

# %% [markdown]
# ## Use Hyperparameter Tuning to Establish Optimal Parameters for Model

# %%
# Establish parameter values
n_estimators_val = [50, 200, 500]
max_depth_val = [3, 4, 5]
min_samples_val = [3, 5, 7]

# %%
# Establish function to create a model
def tune_random_forest(X_train, X_test, y_train, y_test, n_estimators_val, max_depth_val, min_samples_val):
   
    rf_model = RandomForestClassifier(n_estimators=n_estimators_val, max_depth = max_depth_val, min_samples_leaf = min_samples_val, random_state=78)
    
    start_time = time.time()
    
    rf_model.fit(X_train, y_train)
    
    end_time = time.time()
    
    total_time = end_time - start_time
    
    predictions = rf_model.predict(X_train)
    accuracy_score_train = accuracy_score(y_train, predictions)
    
    predictions_test = rf_model.predict(X_test)
    accuracy_score_test = accuracy_score(y_test, predictions_test)
    
    return total_time, accuracy_score_train, accuracy_score_test

# %%
# List expression to consolidate nested for loop
parameters = [(n, m, s) for n in n_estimators_val for m in max_depth_val for s in min_samples_val]

# %%
# Create for loop to search through selected parameters for hyperparameter tuning
parameter_tuning = {}
            
for (n, m, s) in parameters:
    results = tune_random_forest(X_train, X_test, y_train, y_test, n, m, s)
    parameter_tuning[(n, m, s)] = results

# %%
# Pretty Print results
import pprint
pprint.pprint(parameter_tuning)
# Out:
# {(50, 3, 3): (1.637690782546997, 0.7007111177184767, 0.6994722366758344),
#  (50, 3, 5): (1.253061294555664, 0.7008350058227409, 0.6997695681260685),
#  (50, 3, 7): (1.6107172966003418, 0.7003890086473897, 0.6995465695383929),
#  (50, 4, 3): (1.4310712814331055, 0.6876037562873213, 0.6910726232067197),
#  (50, 4, 5): (2.0267488956451416, 0.6917416189697465, 0.6933026090834759),
#  (50, 4, 7): (2.0275418758392334, 0.6978864689412523, 0.6989519066379246),
#  (50, 5, 3): (1.1457369327545166, 0.7101018360217052, 0.7111424960975247),
#  (50, 5, 5): (0.8872299194335938, 0.7019995540028247, 0.703709209841671),
#  (50, 5, 7): (0.8849823474884033, 0.7109194975098491, 0.7127778190738125),
#  (200, 3, 3): (2.439213514328003, 0.6901806288560173, 0.6934512748085929),
#  (200, 3, 5): (3.948788642883301, 0.690230184097723, 0.69359994053371),
#  (200, 3, 7): (2.755213737487793, 0.689908075026636, 0.6938972719839441),
#  (200, 4, 3): (2.904660940170288, 0.6895364107138433, 0.6921132832825392),
# ...

# %% [markdown]
# ## Fitting the Model

# %%
# Create a random forest classifier
rf_model = RandomForestClassifier(n_estimators=200, max_depth = 5, min_samples_leaf = 7, random_state=78)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train, y_train)

# %% [markdown]
# ## Making Predictions Using the Random Forest Model

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test)

# %% [markdown]
# ## Model Evaluation

# %%
# Calculating the confusion matrix for y_train
predictions_train = rf_model.predict(X_train)

cm = confusion_matrix(y_train, predictions_train)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_train, predictions_train)

# %%
# Displaying results for y_train
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_train, predictions_train))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0        12372         7805
# Actual 1         3693        16489
# Accuracy Score : 0.7151069154339801
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.77      0.61      0.68     20177
#            1       0.68      0.82      0.74     20182
#
#     accuracy                           0.72     40359
#    macro avg       0.72      0.72      0.71     40359
# weighted avg       0.72      0.72      0.71     40359

# %%
# Plot confusion matrix in a display
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_train, predictions_train)
cmd_obj = ConfusionMatrixDisplay(cm, display_labels=['SEV 0', 'SEV 1'])
cmd_obj.plot()
cmd_obj.ax_.set(
                title='Train Data Confusion Matrix Display', 
                xlabel='Predicted Results', 
                ylabel='Actual Results')

plt.savefig("Output/Train_Confusion_Matrix.png")

plt.show()

# sns.heatmap(cm,annot=True,fmt="d")

# %%
# Calculating the confusion matrix for y_test
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results for y_test
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0         4143         2586
# Actual 1         1216         5508
# Accuracy Score : 0.7173864565524418
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.77      0.62      0.69      6729
#            1       0.68      0.82      0.74      6724
#
#     accuracy                           0.72     13453
#    macro avg       0.73      0.72      0.71     13453
# weighted avg       0.73      0.72      0.71     13453

# %%
# Plot confusion matrix in a display
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, predictions)
cmd_obj = ConfusionMatrixDisplay(cm, display_labels=['SEV 0', 'SEV 1'])
cmd_obj.plot()
cmd_obj.ax_.set(
                title='Test Data Confusion Matrix Display', 
                xlabel='Predicted Results', 
                ylabel='Actual Results')

plt.savefig("Output/Test_Confusion_Matrix.png")

plt.show()

# sns.heatmap(cm,annot=True,fmt="d")

# %% [markdown]
# ## Feature Importance

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf_model.feature_importances_
# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.30822929645935926, 'Year'),
#  (0.2927551083279034, 'Distance(mi)'),
#  (0.08064746217328911, 'Wind_Chill(F)'),
#  (0.07036356504473494, 'Weather_Condition_Fair'),
#  (0.05842318899699211, 'Weather_Condition_Clear'),
#  (0.047616936168381634, 'Weather_Condition_Overcast'),
#  (0.01947328053761515, 'Crossing'),
#  (0.016240790064010396, 'Traffic_Signal'),
#  (0.014394599271384234, 'Weather_Condition_Cloudy'),
#  (0.01270788992547166, 'Wind_Speed(mph)'),
#  (0.008350721687562094, 'Weather_Condition_Scattered Clouds'),
#  (0.008060453454053809, 'Humidity(%)'),
#  (0.00772914994015232, 'Pressure(in)'),
#  (0.006252298631004459, 'Weather_Condition_Unavailable'),
#  (0.006047280948050817, 'Stop'),
#  (0.005963702687989817, 'Sunrise_Sunset_Unavailable'),
#  (0.004948195578213748, 'Visibility(mi)'),
#  (0.003628729528169761, 'Precipitation(in)'),
#  (0.003592267558563042, 'Give_Way'),
#  (0.0029950562239049894, 'Wind_Direction_CALM'),
#  (0.0021556952059984627, 'Junction'),
# ...

# %%
# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')[-10:]
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)

plt.savefig("Output/Feature_Importance.png")
